# %%
import pandas as pd
from pathlib import Path

# %%
glassdoor_data_to_load = Path("glassdoor_reviews.csv")
#csv_path = "Project_4/Bedbug_Reporting.csv"
glassdoor_data_df = pd.read_csv(glassdoor_data_to_load)
glassdoor_data_df.head()
# Out:
#                     firm date_review              job_title
# 0  AFH-Wealth-Management  2015-04-05                         \
# 1  AFH-Wealth-Management  2015-12-11   Office Administrator
# 2  AFH-Wealth-Management  2016-01-28   Office Administrator
# 3  AFH-Wealth-Management  2016-04-16
# 4  AFH-Wealth-Management  2016-04-23   Office Administrator
#
#                               current                      location
# 0                    Current Employee                           NaN  \
# 1  Current Employee, more than 1 year  Bromsgrove, England, England
# 2  Current Employee, less than 1 year  Bromsgrove, England, England
# 3                    Current Employee                           NaN
# 4  Current Employee, more than 1 year  Bromsgrove, England, England
#
#    overall_rating  work_life_balance  culture_values  diversity_inclusion
# 0               2                4.0             3.0                  NaN  \
# ...

# %%
 glassdoor_data_na = glassdoor_data_df.dropna()

# %%
glassdoor_data_na.columns
# Out:
# Index(['firm', 'date_review', 'job_title', 'current', 'location',
#        'overall_rating', 'work_life_balance', 'culture_values',
#        'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt',
#        'recommend', 'ceo_approv', 'outlook', 'headline', 'pros', 'cons'],
#       dtype='object')

# %%
glassdoor_data_drop =  glassdoor_data_na.drop(columns=['headline', 'pros', 'cons','recommend', 'ceo_approv', 'outlook'])

# %%
glassdoor_data_drop
# Out:
#                          firm date_review
# 50      AFH-Wealth-Management  2020-10-01  \
# 51      AFH-Wealth-Management  2021-02-05
# 52      AFH-Wealth-Management  2021-02-07
# 53      AFH-Wealth-Management  2021-02-07
# 60      AFH-Wealth-Management  2021-05-12
# ...                       ...         ...
# 838556         the-LEGO-Group  2021-05-21
# 838558         the-LEGO-Group  2021-05-25
# 838560         the-LEGO-Group  2021-05-31
# 838561         the-LEGO-Group  2021-06-02
# 838565         the-LEGO-Group  2021-06-04
#
#                                   job_title
# 50                     Office Administrator  \
# 51                          Quality Control
# 52                        IFA Administrator
# 53                    Investment Operations
# 60              Client Engagement Executive
# ...                                     ...
# 838556   Sales Associate (Brick Specialist)
# 838558               Senior Product Manager
# 838560           Senior Experience Designer
# ...
