# %%
import pandas as pd
from pathlib import Path

# %%
HR_analytics_to_load = Path("hr_analytics.csv")
#csv_path = "Project_4/Bedbug_Reporting.csv"
HR_analytics_data = pd.read_csv(HR_analytics_to_load)
HR_analytics_data
# Out:
#        empid  satisfaction_level  last_evaluation  number_project
# 0          1                0.38             0.53               2  \
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 14994  14995                0.40             0.57               2
# 14995  14996                0.37             0.48               2
# 14996  14997                0.37             0.53               2
# 14997  14998                0.11             0.96               6
# 14998  14999                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident
# 0                       157                   3              0  \
# ...

# %%
HR_analytics_data.dropna()
# Out:
#        empid  satisfaction_level  last_evaluation  number_project
# 0          1                0.38             0.53               2  \
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 14994  14995                0.40             0.57               2
# 14995  14996                0.37             0.48               2
# 14996  14997                0.37             0.53               2
# 14997  14998                0.11             0.96               6
# 14998  14999                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident
# 0                       157                   3              0  \
# ...

# %%
drop_columnd = HR_analytics_data.drop(columns =['empid', 'number_project', 'left'])
drop_columnd
# Out:
#        satisfaction_level  last_evaluation  average_montly_hours
# 0                    0.38             0.53                   157  \
# 1                    0.80             0.86                   262
# 2                    0.11             0.88                   272
# 3                    0.72             0.87                   223
# 4                    0.37             0.52                   159
# ...                   ...              ...                   ...
# 14994                0.40             0.57                   151
# 14995                0.37             0.48                   160
# 14996                0.37             0.53                   143
# 14997                0.11             0.96                   280
# 14998                0.37             0.52                   158
#
#        time_spend_company  Work_accident  promotion_last_5years  salary
# 0                       3              0                      0     low
# ...
